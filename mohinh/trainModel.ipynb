# %%
import os
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers
from tensorflow import keras
import tensorflow as tf
from emot.emo_unicode import UNICODE_EMOJI, EMOTICONS_EMO
from sklearn.preprocessing import LabelEncoder
from underthesea import word_tokenize

# %%
path = './balanced_data.csv'
def readdata(path):
    list_file = os.listdir(path)
    data = pd.DataFrame()
    for filename in list_file:        
        data = pd.concat([data, pd.read_csv(os.path.join(path, filename), sep=',')])
    return data['content'], data['label']

# %%
def remove_emoji(text):
    for emoji in UNICODE_EMOJI.values():
        text = text.replace(emoji, "")
    for emoticon in EMOTICONS_EMO.values():
        text = text.replace(emoticon, "")
    return text

def clean_text(text):
    text = text.lower()
    text = remove_emoji(text) 
    text = re.sub(r'\d+', ' ', text)  
    text = re.sub(r'[^\w\s]', ' ', text)  
    text = re.sub(r'\s+', ' ', text).strip()  
    
    words = word_tokenize(text, format="text")
    return words

def preprocess_data(file_csv):
    df = pd.read_csv(file_csv)
    
    df = df[['content', 'label']].dropna()

    df['content'] = df['content'].fillna('')
    df['content'] = df['content'].apply(clean_text)

    label_encoder = LabelEncoder()
    df['label'] = label_encoder.fit_transform(df['label'])

    return df, label_encoder

file_csv = './balanced_data.csv'
data, label_encoder = preprocess_data(file_csv)

reviews = data['content'].tolist()
labels = data['label'].tolist()
reviews
# Out:
# ['túi ưng_ý lắm',
#  'mùi thơm dễ_chịu',
#  'chất_lượng sản_phẩm rất kém hàng bị lỗi tưa đường chỉ từ trên xuống dưới',
#  'sp quá tệ',
#  'giá tiền đi_đôi với chất_lượng nói_chung k nên mua mặc_tí đã rách tứ_tung mà bạn nào dưới kg mới vừa nhé_k có mà trật_ních mua về nhớ mang đi may lại toàn_bộ',
#  'shop giải_thích cho mình đc ko',
#  'hàng_không đúng mẫu shop phục_vụ tạm được',
#  'mặc_tiện cho con bú',
#  'thời_gian giao hàng tạm được',
#  'lại đặt tiếp thêm cái nữa em nhé',
#  'trên cả tuyệt_vời',
#  'shop giao hàng cực nhanh',
#  'm mua kiểu áo khác nhau nhưng áo nào vải cũng rất đẹp',
#  'giá_cả chấp_nhận được',
#  'chất_lượng sản_phẩm tạm được giá_cả chấp_nhận được thời_gian giao hàng rất nhanh',
#  'hàng cực đẹp đẹp hơn trên ảnh nhiều chủ_shop tận_tâm nhất mà mình từng gặp',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'vải đẹp chắc_chắn hợp giá tiền',
#  'm kg mặc ôm ko đc thoải_mái hơi buồn',
#  'sản_phẩm tạm được',
#  'bảo cường_lực mà ship cho nilon dán màn đã thế lại còn k dán được vào đt',
#  'hang ko giong hinh',
#  'chất vải mặc vào gây ngứa dặm',
#  'vải mỏng à nhỏ nữa',
#  'xe đẹp và chắc chăn bé rất thích',
#  'hàng giống hình',
#  'tư_vấn dễ_thương nhiệt_tình hàng đúng hình_đẹp sẽ ủng_hộ shop',
#  'áo mỏng và còn sổ chỉ',
#  'cam on',
#  'shop làm_việc rất chuyên_nghiệp',
#  'chất_lượng sản_phẩm tốt đóng_gói sản_phẩm chắc_chắn',
#  'ko mua hơi phí',
#  'vải mỏng nè k bo_gấu tay_áo gấu quần nè_hình in chưa nét lắm nè so với tần_giá thì ổn',
#  'quần chất hơi mỏng nhưng phù_hợp giá tiền thấm hút tốt ko bị bí_da',
#  'chất_lượng sản_phẩm rất kém',
#  'điều_kiện áp_dụng ko giống mô_tả mình sử_dụng vào ngày thứ thì cửa_hàng xác_nhận là ko áp_dụng cùng với các khuyến_mãi khác mong_shop kiểm_tra',
#  'đặt_hàng ngày ko thấy giao',
#  'mua về cái bịt mắt đi ngủ luôn giấc ngon_lành',
#  'màu áo_k như hình',
#  'chất vải rất đẹp',
#  'đã note rất rõ_ràng là đen đỏ hoặc rằn_ri mà vẫn không giao đúng hàng',
#  'vải tạm được',
#  'cổ quá rộng',
#  'nhưng hơi thất_vọng',
#  'bán hàng k có trách_nhiệm đặt trắng đen mà giao cho khách đen mình sợ giao_nhầm đã nt riêng r v mà vẫn cố_tình giao màu sai đã v khi nhận đc hàng thì cái bị bay màu hàng lỗi đt khiếu_nại thì chửi khách thậm_tệ có dấu_hiệu lừa_đảo nên cẩn_thận shop phục_vụ rất kém',
#  'k pải lớp',
#  'chất_lượng sản_phẩm ok_hợp với giá tiền',
#  'chất vải xấu',
#  'vải mềm_form này kiểu k như sơ_mi thường đâu nhá_vạt trc rất dài và trễ vai nữa cánh_tay cx kiểu rộng_ý ổn',
#  'đóng_gói sp cẩn_thận hàng ok nhưng giao hàng quá lâu mặc_dù trả phí ship khá cao',
#  'váy hơi dài tuy_nhiên shop tư_vấn nhiệt_tình',
#  'sản_phẩm đẹp m rất ưng ta',
#  'hỏi shop thì bảo tại_sao bạn mua hàng k vừa mà shop phải chịu phí vc',
#  'shop lưu_ý hơn nhé',
#  'ko có time nên ko chụp hình đc',
#  'sai chuẩn của nó là l mà shop dán đè lên là m',
#  'chất vải hơi nóng',
#  'đặt size thì shop giao',
#  'áo màu trắng phải mặc thêm áo_lót bên trog thì ok',
#  'y_chang hình',
#  'túi chắc_chắn y_hình',
#  'chất_lượng sản_phẩm tốt',
#  'sản_phẩm rất đẹp chắc_chắn',
#  'chưa biết lắp_đặt ntn',
#  'vải mềm và mát_mng cứ yên_tâm mua đi nh',
#  'hàng bị lỗi liên_lạc vs shop đổi hàng nhưng ko đc giải_quyết ổn thỏa nhắn_tin shop ko_thèm trả_lời ko hài_lòng',
#  'đóng_gói sản_phẩm tạm được đóng_gói sản_phẩm sơ_xài',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'chờ mấy ngày trời mua quần về làm rẻ lau',
#  'thời_gian giao hàng nâu sản_phẩm tạm đc nói_chung k_ưng cho lắm',
#  'vẫn se tiep tuc ung_ho shop chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiề',
#  'áo mỏng from nhỏ',
#  'thời_gian giao chậm',
#  'hàng đẹp phù_hợp với giá tiền',
#  'không_thể chấp_nhận được',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'áo không bị lỗi vải thun_ổn phù_hợp với giá tiền nói_chung đáng mua',
#  'nhìn_chung tạm ổn',
#  'chưa xài thử nếu k tốt quay lại sửa oánh giá không sửa coi như chấp_nhận',
#  'áo rách dính mực_nt thì shop k tl',
#  'tạm ổn so với giá',
#  'thích nhất sợi dây',
#  'tôi rất hài_lòng về sản_phẩm',
#  'không có mùi mấy',
#  'phù_hợp với giá tiền',
#  'áo in bị lem màu sản_phẩm tạm được',
#  'váy rất xinh_chất vải mát_lịm lun',
#  'đơn nào cũng nhanh_chóng',
#  'chất vải dày_dặn rất đáng tiền',
#  'shop phục_vụ rất tốt nhưng có_vẻ quần_chật so với mình',
#  'ta nói đẹp ko chịu đc là có thật cảm_ơn shop rất nhiều sẽ ủng_hộ tiếp',
#  'vải êm kg mặc sz s vẫn hơi rộng nhưng váy đẹp',
#  'giao hàng lâu quá',
#  'hỗ_trợ nhiệt_tình sau bán hàng',
#  'ch sử_dụng',
#  'đồ đẹp đóng_gói cẩn_thận chắc_chắn',
#  'áo gì thun mỏng còn hơn giấy',
#  'hàg ok lắm',
#  'nhận được áo rồi ạ',
#  'chất_lượng sản_phẩm kém không đáng tiền áo vải xau ma shop ghi là vải voan áo ko giống trong hinh',
#  'áo rất rất rất đẹp',
#  'k đẹp',
#  'form giày cứng_cáp đóng_gói ổn',
#  'đúng là tiền nào của đấy',
#  'mua ở đây c mà dùng thành cùi nhất nhà ko nên mua',
#  'phun mạnh_hương tinh_dầu sả bay khắp phòng thích quá thích lun đèn led đổi màu rất đẹp mình hài_lòng lắm',
#  'thời_gian giao hàng nhanh',
#  'do gói hàng túi hơn méo mất form_vân cho',
#  'nếu mua mặc ngủ ở phòng riêng thì ok',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền rất đáng tiền rất đáng tiền thời_gian giao hàng rất nhanh',
#  'vãi đẹp nhưng áo nam size cho người kg mặc chật_shop không cho đổi trả buôn_bán k uy_tín',
#  'chất_lượng sản_phẩm tuyệt_vời shop phục_vụ rất tốt rất đáng tiền',
#  'dởm',
#  'giao hàng hơi lâu áo hơi chật',
#  'mình mua màu đen mà giao màu_da hơi buồn tí',
#  'màu_sắc giống mẫu có_điều túi khá nhỏ không_gian chứa ít',
#  'bán quần_rách mà cũng bán đc đành',
#  'mặc bị tụt k ôm bụng',
#  'giá rẻ sản_phẩm ok',
#  'chất_lượng sản_phẩm tuyệt_vời sẽ tiếp_tục ủng_hộ shop trong tương_lai',
#  'đẹp lắm ạ nhưng hơi rộng_xí',
#  'hàng chuẩn nè',
#  'mới dùng lần đầu_tiên',
#  'thủ_tục đổi trả phức_tạp',
#  'cũng đc nhưng hơi ngắn',
#  'thất_vọng',
#  'giao hàng chậm',
#  'giá rẻ',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền thời_gian giao hàng rất nhanh_shop chăm_sóc khách_hàng rất tốt tư_vấn nhiệt_tình',
#  'nhưng màu sản_phẩm k đúng như hình quảng_cáo side xl rộng như xxl vậy',
#  'áo chất vải dày dặn màu đỏ_đô rất đẹp',
#  'chưa có sản_phẩm',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn noi chung là đep cảm_ơn sop ui nha',
#  'động tí là bong ra rất chán',
#  'sẽ ủng_hộ shop nhiều',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'địu rất đẹp và nhẹ bé ngồi rất hợp_tác ạ',
#  'đằng này bán xong phủi tay luôn à',
#  'sp phom bộ_đồ to',
#  'chủ shop vục vụ rất nhiệt_tình chu_đáo',
#  'thích_hợp các bạn nhỏ làm nháp vẽ hình_thư giãn',
#  'chất_lượng sản_phẩm kém đóng_gói sản_phẩm kém',
#  'hixx',
#  'đẹp lắm shop rất ưng_ý',
#  'bọn lừa_đảo còn thiếu mẹ mày tiền mẹ m ib ko tl thôi bà mày biếu dmm làm_ăn thất_đức kieru này đéo tồn_tại dk mãi đâu',
#  'bung chỉ vải tạm',
#  'chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém',
#  'mình kg mà mặc hơi_kích',
#  'thời_gian giao hàng nhanh',
#  'quần xinh vải hơi mỏng_xíu lên dáng xinh',
#  'chất vải đẹp',
#  'áo form rộng nên mọi ng đặt thì giảm xuống sz',
#  'may nhỏ xay k duoc',
#  'chất_lượng sản_phẩm tạm được shop giao hàng quá chậm',
#  'vải rất mềm',
#  'chẳng_lẽ mình trả lại hàng',
#  'đặt kiểu trắng vàng_đen mà giao hồng vàng trắng',
#  'do chân mình to ngang nên phải đổi size to và được shop hỗ_trợ kịp_thời',
#  'shop nên xem_lại cách đóng_gói',
#  'chất_lượng sản_phẩm không như hình đăng_bán không hài_lòng chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'chị mây nhiệt_tình lắm nên châu_gửi hình_review cho các bạn coi hàng chị mây bán luôn nè',
#  'áo hơn ngắn',
#  'áo_khoác bị lỗi do may dính chùm không mặc được',
#  'tiền nào của đấy',
#  'tóc quá ít sử_dụng lộ hết tóc thật',
#  'nghe review miêu_tả ghê_gớm lắm mà',
#  'cứ nghĩ m là vừa mà phom nhỏ quá lại ko ních dk',
#  'chán',
#  'áo đẹp vải hơi mỏng nhưng với giá tiền thì ok',
#  'sẽ ủng_hộ shop tiếp_tục',
#  'mặc dễ xù',
#  'chất_lượng sản_phẩm tuyệt_vời tuy chờ_đợi hơi lâu',
#  'ngắn quá',
#  'màu lợt hơn hình',
#  'kb giặt có phai màu k nhưng thui giá rẻ vẫn vote shop',
#  'chất_lượng sản_phẩm rất kém tôi đã làm theo hướng_dẫn trả hàng và bên shop nói với tôi như_thế sẽ gây khó_khăn khi giao_nhận của shop nên bấm hủy trả hàng và gởi hàng lại địa_chỉ nơi gởi kèm thu hộ cod cho nhanh kết_quả là bên shop không nhận lại hàng và bên shopee không_thể quyết vì quá thời_gian',
#  'chất_lượng ok chủ shop thân_thiện',
#  'mua lần thứ hai phải nói là chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền thời_gian giao hàng rất nhanh rất đáng tiền rất đáng tiền rất đáng tiền rất đáng tiền rất đáng tiền rất đáng tiền rất đáng tiền đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'áo đẹp nhóe đáng tiền',
#  'áo bò hơi rộng mà ks',
#  'mình có ảnh mô_tả',
#  'đáng tiền thời_gian giao hàng rất nhanh đi khá ôm chân phần thân giày vài hơi mỏng',
#  'nó bị phai màu xanh xanh j ra ấy bị bẩn nữa',
#  'chất thì ok nhưng đặt sz thì có chiếc sz',
#  'vải ngoài tốt nhưng lớp lót ko đc tốt lắm',
#  'sice s nhưng to quá',
#  'tin_tưởng shop sẽ tiếp_tục ủm hộ',
#  'thất_vọng áo_k giống hình màu_đô nhìn giống màu nâu tệ',
#  'rất không đáng tiền',
#  'giao hàng nhanh đóng_gói cẩn_thận phục_vụ nhiệt_tình',
#  'tốt hơn merries',
#  'mình kg mà mặc xxl mèo vẫn vừa luôn',
#  'vải đẹp giao hàng nhanh mua quần mà quần quá bó_hơi buồn_tí nhưng sop phục_vụ tốt sao nha sop mình rút kn sẽ liên_hệ sop tư_vấn trước khi đặt_hàng',
#  'thoáng mát',
#  'đúng là sai sự_thật',
#  'shop ổn nhưng chưa hoàn_hảo',
#  'lúc đầu m nghĩ k hết ai dè chỉ chấm có xíu rồi lau đi để cho nó tự_tạo mài rồi tự lột cái vết gai_chân như tua_bạch_tuột đi bắn lần mà k hết giờ bôi có lần là tróc luôn rồi không đau mà hiệu_quả quá_chừng',
#  'mỗi tội mùi hơi khó_chịu',
#  'thời_gian giao hàng rất nhanh rất đáng tiền chất_lượng sản_phẩm tuyệt_vời',
#  'shop phục_vụ rất tốt thời_gian giao hàng rất nhanh',
#  'shop phục_vụ tôt',
#  'hàng sấu',
#  'còn tính_năng khác cần thời_gian thể_nghiệm',
#  'áo không to như mình tưởng',
#  'bự quá không mặc đc kiểu thì ko như mình đã đặt',
#  'hàng đẹp đúng như hình chắc_chắn',
#  'bị rách một xíu đó đóng_gói sản_phẩm rất kém giá_cả chấp_nhận được',
#  'không như những shop khác mình từng mua bên họ làm hư_đồ mình nói đổi lại mà k thấy đâu',
#  'thất_vọng',
#  'lắp phát sẵn dùng',
#  'làm_ăn có tâm_tí nhé_shop phục_vụ rất kém',
#  'thời_gian giao hàng rất nhanh chất_lượng sản_phẩm tuyệt_vời shop phục_vụ rất tốt rất đáng tiền',
#  'chất siêu_mềm và đẹp',
#  'nt k tl',
#  'áo vừa đẹp lắm',
#  'sản_phẩm đẹp nhưng cứng quá',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn thời_gian giao hàng rất nhanh',
#  'giá_cả chấp_nhận được',
#  'mua áo một đằng gửi một nẻo',
#  'mà nút này là nút bọc lấy đâu mà gắn vào đây',
#  'm kg mà mặc ko vừa hình_như tke cho hs tiểu_hoc',
#  'không giải_đáp',
#  'giao ko đúng ý khách',
#  'áo xấu đường may cẩu_thả',
#  'vải quá dởm',
#  'va i hơi mo_ng nhưng from đe p giô ng hi_nh',
#  'cực ưng màu áo',
#  'áo đẹp lắm cj',
#  'vải đẹp chuẩn hi_vọng sẽ có nhiều sản_phẩm tốt hơn_nữa',
#  'thời_gian giao hàng rất nhanh',
#  'hàng_không giống hình',
#  'vải mềm mịn mướt_sờ rất thích nhưng cũng đồng_nghĩa với mỏng có cảm_giác mong_manh dễ vỡ không biết dùng tgian sẽ thế_nào',
#  'mùi hôi_ko chịu dc',
#  'shop có chat và tư_vấn nhưng ko nhiệt_tình lắm có_thể do nhiều đơn quá trả_lời ko kịp',
#  'size nhưng mặc chật_ko co_dãn nhiều',
#  'chất_lượng vải nói_chung cũng ổn',
#  'áo may_lỗi ở cổ và ống_tay vải áo thì quá mỏng_mảnh lại quá rộng',
#  'mua lần rất hài_lòng',
#  'shop đăng kiểu mà bán kiểu khi tôi phản_ánh lại với shop thì chối trách_nhiệm',
#  'bàn_tay mỏng nên ko nâng lắm',
#  'hàng đẹp đúng chủng_loại chắc_chắn',
#  'sản_phẩm rất chắc đẹp',
#  'thanks shop',
#  'váy quá mỏng ko ưng_ý',
#  'hàg y_hình',
#  'đồ đẹp qa shop ơi c_ơn shop nhìu nhé_shop phục_vụ rất tốt',
#  'vải khá mỏng và rất cũ giao hàng khá nhanh',
#  'hihi',
#  'vải k đẹp',
#  'chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền rất đáng tiền thời_gian giao hàng rất nhanh',
#  'vải mịn nhưng quần_màu thì giặc ra màu nhiều hic màu trắng thì k sao',
#  'ko uy_tín',
#  'váy mát nhưng mỏng',
#  'màu đẹp shop phục_vụ rất tốt',
#  'tiền nào vải ấy với giá đấy thì chất_lượng thế_là đc rồi phần mông_ko co_giãn nói_chung con mình mông to ko mặc đc',
#  'đóng_gói đẹp gọn_gàng trong thùng bao_bì chống sốc tận lớp mở mỏi tay lun',
#  'kiểu_dáng ok',
#  'giao_hành nhanh sáng đặt chiều đã có hàng',
#  'chúc shop một ngày tốt_lành',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn chất_lượng sản_phẩm tuyệt_vời rất đáng tiền thời_gian giao hàng rất nhanh rất đáng tiền',
#  'vẫn ưng như ngày đầu chất_lượng sản_phẩm tuyệt_vời rất đáng tiền',
#  'bên mình bán không kèm pin sao',
#  'đẹp y_hình',
#  'đẹp lại rẻ',
#  'màu xấu',
#  'chất_lượng sản_phẩm tương_đối tốt',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'giao hàng thì từ t tuần trước đến t tuần này mới nhận quy_định đổi trả ngày mà_còn mỗi sáng t chờ shop gửi địa_chỉ cụ_thể để ra bưu_điện gửi trả mà shop phản_hồi cực chậm lại ko đưa địa_chỉ cụ_thể',
#  'hàng cực_kỳ đẹp',
#  'áo như hình_chất sờ_hơi cứng ak',
#  'chất_lượng sản_phẩm rất kém',
#  'tuy_nhiên khóa_móc bị mất cái các dây đeo đều lỏng_giặt là tuột ra khỏi áo nên khắc_phục',
#  'giao hàng nhanh lịch_sự',
#  'mua mà nhờ ngta nhận dùm nên chưa thấy cái đầm ra sao haha thời_gian giao hàng rất nhanh',
#  'quần mỏng chứ ko dày',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền thời_gian giao hàng rất nhanh',
#  'khi giặt áo phai màu kinh_khủng_giặt lần vẫn phai đen_ngòm cả nước',
#  'giống hình nhưng vải hơi nhăn chất_lượng sản_phẩm tốt chất_lượng sản_phẩm tốt đóng_gói sản_phẩm chắc_chắn',
#  'sản_phẩm dùng dk',
#  'má xài êm lắm',
#  'vải ok thời_gian giao hàng nhanh ths shop',
#  'lúc đầu nghĩ với giá này thì áo_thun sẽ bị mỏng',
#  'mình check thì thấy shop bán hàng chuẩn giao hàng nhanh đóng_gói sản_phẩm đẹp',
#  'dây hơi dài',
#  'may nơ hơi xấu',
#  'vừa tầm giá',
#  'chất vải mỏng mình phải may thêm lớp lót dù để bậy mặc cũng mát hix',
#  'quan khong_co tui truoc',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'trên hình thấy form rộng lắm mà sao áo_nhân được nó nhỏ_xíu cỡ size m',
#  'bạn nào phân_vân thì mua đi_k hối_hận',
#  'chất_lượng sản_phẩm tuyệt_vời thanks_shop khi tư_vấn thêm thank_nối giảm bớt chi_phí khi hạ sz',
#  'kiểu đẹp vải êm_shop phục_vụ tốt',
#  'mỗi tội đi mua quần mới để hợp vs giày k',
#  'hơi mặn',
#  'sau ủng_hộ shop tiếp',
#  'nc là vs giá tiền là ưng yên_tâm mua nhé mn',
#  'shop ơi cái quần cùng size mà sao cái nhỏ cái bự cái nhỏ mặc hok vừa thời_gian giao hàng rất nhanh',
#  'hơi thất_vọng về sản_phẩm vì không phải hàng của xiaomi như hình quảng_cáo mình có xem review trước tren youtube rồi nên mới đặt mua',
#  'hoodie thì vải quá mỏng',
#  'chắc phải đem sửa',
#  'quá okie với giá như thế_này',
#  'vải đẹp in hơi to và tệ',
#  'đóng_gói ko đẹp lắm',
#  'chất_lượng sản_phẩm khá tuyệt_vời',
#  'hàng tạm được chứ không đẹp đóng_gói ok',
#  'cổ áo không giống_hình lắm',
#  'sp chưa sử_dụng chưa biết chất_lượng thế_nào',
#  'ủng_hộ dài dài',
#  'đồ đẹp laqms luôn ạ',
#  'chất_lượng sản_phẩm mỏng',
#  'chất_lượng tạm được',
#  'nhưng không thấy shop gửi voucher qua tin nhắn hay_là chat trên shopee',
#  'màu hơi vàng chứ ko phải trắng',
#  'màu hồng sến ko đúng với hình',
#  'đẹp như hình',
#  'đúng là shopee h giao hàng rất nhanh trong ngày mà_còn có bịch kẹo thôi mà nhìn cái hộp và keo dán đều của shopee hết mà bên trong lót đều mút bảo_vệ nữa chứ hôm_nay dù km mà nhắn_shop giao_bịch kẹo date mới đúng y_chang nsx lun làm_ăn rất có tâm gần hết kẹo sẽ gặp shop lần thanks',
#  'hơi tiếc_chút là áo mình bị lủng_lỗ nhỏ đằng trước',
#  'size xl không vừa cho người kg như shop ghi đâu',
#  'mong ad điều_chỉnh lại',
#  'quần dày_dặn đẹp lắm sẽ ủng_hộ shop',
#  'trắng thì bự',
#  'mình kg cao m mà mặc size m còn hơi rộng nên mn hãy lựa size cho kĩ_trc khi mua',
#  'áo nhìn xinh_shop nói_chuyện cực_đáng yêu',
#  'hok giống như hình một_chút nào',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'túi váy hơi cạn',
#  'chất_lượng sản_phẩm tạm được shop phục_vụ tạm được thời_gian giao hàng tạm được',
#  'đóng_gói kỹ',
#  'chất áo cứng quá',
#  'giao hàng chậm chễ',
#  'cái mất cổng sạc',
#  'bị rụng mất hạt chuông',
#  'quần không có bo_viền nên mặc dễ_chịu hạn_chế mùi tầm so với quần_cotton',
#  'giống hình',
#  'size ao nho_hon nhung sp khac',
#  'đóng_gói sản_phẩm rất kém',
#  'mát và dễ_ủi',
#  'shop rút kinh_nghiệm nhé',
#  'vải áo hơi mỏng nhưg_k đến_nỗi nào mặc ổn so với giá tiền thì áo khá ok_đường chỉ may đẹp fom áo đẹp tất_cả đều rất đẹp nếu đổi qua vải đẹp hơn thì sp tuyệt_vời',
#  'áo chất đẹp nhé_shop phục_vụ rất tốt thời_gian giao hàng rất nhanh',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'eo mk_cm nhưng mặc size_l vẫn rộng shop phục_vụ rất tốt',
#  'quần_lót rất rất tốt',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'nhưng áo_hơi rộng',
#  'hàng chất_lượng tạm được so với mức giá',
#  'nhưng k_sao nhìn_xa thì cũng đk',
#  'cơ mà tôi mua hôm_nay ngày_mai shop làm flash sale là sao',
#  'có_điều gói hơi chắc quá',
#  'áo dày dài rộng mk m mặc thì thành váy',
#  'quan thun nho qua size l ma ao rong qua k mac vua',
#  'hàng đẹp y_hình',
#  'thời_gian giao hàng rất nhanh rất đáng tiền shop phục_vụ rất tốt đóng_gói sản_phẩm rất đẹp và chắc_chắn chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'đẹp',
#  'áo form nhỏ cứng k êm',
#  'ok lắm nhé',
#  'đẹp lắm shop ơi mình mập cứ sợ ko vừa ai_ngờ vừa y cảm_ơn shop',
#  'túi_xách đẹp_ghê chất_lượng quá tuyệt so với giá',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'rất rất rất là hài_lòng lần đầu_tiên có shop làm mình hài_lòng đến vậy sản_phẩm rất chi là ok',
#  'quần đẹp ưng lắm',
#  'gọi gọi cả ảnh luôn à',
#  'đóng_gói sản_phẩm tạm được',
#  'nách bị rộng',
#  'mặc thoải_mái',
#  'chất mịn_mát mỗi tội_chất này dễ bị nhăn nói_chung là phù_hợp giá tiền',
#  'mua quan dài lửng',
#  'đẹp',
#  'sản_phẩm tạm dc',
#  'nên mặc lên không cứng form',
#  'hơi chật nhưng cũng dc',
#  'có vạch báo đầy',
#  'giống như hình',
#  'hàng hơi mỏng ạ',
#  'tuy hộp bị bể',
#  'nhưng_mà thôi cũng được chất_lượng sản_phẩm tuyệt_vời rất đáng tiền',
#  'vải đẹp nhưng nhầm size shop ạ',
#  'lần sau mình sẽ ủng_hộ shop thêm nữa',
#  'eo mông mặc m hơi rộng theo mình',
#  'hơi ít ảnh vi_trg xấp ảnh bts',
#  'chất_lượng tốt mềm dùng rất thích',
#  'rất đáng tiền đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'max xinh luôn',
#  'shop phục_vụ rất tốt rất đáng tiền có kèm quà tặng',
#  'mình đặt trắng be đen xanh rêu lại giao thành màu đen',
#  'rất oke',
#  'được vs giá tiền nha mn hàng ổn_trừ cái cổ_áo thì ổn hơi nhăn',
#  'gửi hàng nhầm đã liên_hệ với shop',
#  'áo đẹp',
#  'ví xấu hàng đểu ko bao_giờ mua hàng của shop nữa_cạch đến già',
#  'cũng duoc tay_hoi ngắn',
#  'châ t_phu hơ p vs gia_tiê n no i chung_la nhâ n xong râ t_la ưng',
#  'giao hàng chậm quá ko sử_dụng đc lúc cần',
#  'còn dùng thì dễ bị vỡ miếng',
#  'đặt màu này giao màu khác',
#  'chi tiê t ma_u đen_bi ra ma_u râ t nhiê_u khi giă t',
#  'nach hơi rông',
#  'chất_lượng sp tốt vải mịn đúng size',
#  'chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền thời_gian giao hàng rất nhanh_shop phục_vụ chưa tốt',
#  'chất_lượng sản_phẩm tuyệt_vời nhưng shop phục_vụ kém quá',
#  'chất_lượng sản_phẩm tuyệt_vời shop phục_vụ rất tốt thời_gian giao hàng rất nhanh quần_hơi bị đẹp nha',
#  'vỏ hộp hơi cũ rách_túi bên trong cũng cũ',
#  'hàng này ko chấp_nhận đc toi tiền',
#  'chất_lượng sản_phẩm rất kém rất không đáng tiền shop phục_vụ rất tốt',
#  'vì bộ phai màu mà hư đống đồ luôn',
#  'chụp sp hơi dìm',
#  'chất vải mềm dày_dặn ôm_dáng',
#  'kể mà ước_lượng được bao_nhiêu kg mặc vừa nữa thì đẹp',
#  'thời_gian giao hàng rất nhanh chất_lượng tạm được so vs giá tiền thì tạm chấp_nhận được',
#  'k giống như hình chất_lượng kém k đáng đồng_tiền',
#  'cạn lời',
#  'đáng tiền',
#  'ret dep đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'áo nhỏ quá mút mỏng nữa đúng là tiền nào của nấy',
#  'ko đu_ng mâ_u trong hi_nh thâ y_giơ i thiê u_la co_kho a_ke o ma ha ng shop giao_la i ko co',
#  'buồn',
#  'vải đẹp mát mỏng mịn',
#  'giày đẹp shop tư_vấn tận_tình',
#  'hình áo tay lỡ mà nhận đc là áo cộc là sao',
#  'size áo ngắn quá k dài như ảnh còn chưa tới đầu_gối nữa',
#  'áo siêu_đẹp luôn',
#  'nc ok',
#  'cảm_ơn shop nhiều nhé',
#  'kiểu ko như mong_muốn',
#  'áo sờ vào mềm mịn nhìn như hình và giao hàng nhanh',
#  'sao bôi vô_hok thấy cảm_giác gì ta',
#  'vải co_dãn tốt mát',
#  'nhưng ko thấm như quảng_cáo kiểu tấm tranh hơn là thảm',
#  'mua cọc tay giao dài tay vải_k co_giãn',
#  'giao hàng nhanh lắm luôn',
#  'giao sai màu sai_kích_cỡ liên_hệ mấy ngày kêu mua lại rồi im_re làm thinh_lớn rồi mà buôn_bán kì_cục quá',
#  'rất ok rất đáng tiền',
#  'cám chất_lượng hạn sử_dụng tận năm giá rẻ bất_ngờ như giá sỉ',
#  'hic hic_ngại chẳng muốn đổi đi đổi lại nữa',
#  'max đẹp chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn thời_gian giao hàng rất nhanh rất đáng tiền shop phục_vụ rất tốt',
#  'rút kinh_nghiệm dáng ko_chuẩn như mình thì ko nên mua đồ online',
#  'sai độ dài',
#  'nt hỏi lại thì trả_lời kiểu phủi tay',
#  'shop rất nhiệt_tình',
#  'chất được đường may hơi lỗi_xíu phù_hợp giá_thành',
#  'vào mở thì có bịch như bị chuột mâm ý',
#  'phù_hợp với tiền',
#  'vãi mỏng',
#  'hai màu hai vải khác nhau cái rộng cái vừa',
#  'mui giày có_vẻ k_đẹp so với giá thì hơi chênh_nhao xíuu',
#  'chỉ trừ vải ra thì form và dáng áo giống hình_mẫu',
#  'tạm được',
#  'thay vào đó là mác đã cài kim băng',
#  'chất luọng tốt mẩu_mã lại đep',
#  'mẫu giống_hình nhưng chất k giống',
#  'nản',
#  'áo đẹp nhưng vải có hơi mỏng so vs mong_đợi',
#  'hơi rộng',
#  'tui bi_loi o_khoa lan dau mua bi vay nen khong bao_gio mua nua',
#  'áo xinh thật_sự',
#  'áo có vài vệt dơ nhỏ',
#  'mặc rất thích',
#  'shop ban hang dieu',
#  'màu lên màu hồng_ko phải màu cam hicc',
#  'tay_áo quá dài',
#  'cái này bj vết bẩn ngay gần con hươu ạ hjxx k biết có giặt sạch đc ko nữa',
#  'hàng rất đẹp vải êm',
#  'tuy_nhiên shop ghi fz cho ai tới kg thì k phải nha',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'shop đổ do shopee tính shopee nói do shop tính phí',
#  'nhân_viên giao hàng kì_kèo xin thêm tiền',
#  'hịn',
#  'hộp to giày đẹp giao nhanh',
#  'không giống như sản_phẩm đã đặt như đồ_chơi vẹy ák',
#  'giao hàng nhanh và đóng_gói hàng tốt',
#  'quần chất đẹp giá rẻ nhưng chất rất dày_dặn chỉ có_điều nếu các bạn mua thì phải chọn nhỉnh lên size mặc cho đẹp và dễ_chịu chút a_chốt lại rất truất',
#  'vải không được dày_dặn cho lắm',
#  'chất_lượng sản_phẩm tuyệt_vời tư_vấn nhiệt_tình love_u',
#  'trước đã mua áo này ở shop khác',
#  'màu_sắc kiểu_dáng giống ảnh',
#  'sẽ đặt mua ủng_hộ shop tiếp',
#  'tại mình cần hàng nên hỏi',
#  'giảm cân nhẹ_nhàng ko mệt_mỏi như những loại trước đó m đã dùng mua thêm vì m là mẹ bỉm sữa nên vẫn ăn_nhìu tháng vừa_rồi mới giảm kg',
#  'chất_liệu sản_phẩm tuyệt_vời',
#  'mặc đẹp mà ra màu wa giặt vài lần ko pít hết ko phơi gần cái áo thì áo bị dính màu luôn',
#  'hàng_không như mô_tả thái_độ shop kém',
#  'vải đẹp',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'vì dép bé',
#  'chất luog ổn',
#  'shop phục_vụ rất tốt',
#  'chất áo thì k phải lăn_tănnn luôn nhưng form hơi to',
#  'chất_lượng sản_phẩm tốt chất ren tạm được hơi mỏng',
#  'chuẩn chất kate_thái mềm mịn_mát nhẹ thoải_mái ko nhăn nếu có nhăn nhẹ mặc vào chút là hết',
#  'mình chọn màu_da shop giao màu đen',
#  'mình kg mặc size_xxl rất rộng chất_lượng sản_phẩm tuyệt_vời',
#  'váy đẹp lắm shop ơi',
#  'chất_lượng sản_phẩm tốt nhưng có cái thiếu tem mác',
#  'chỉ mỗi tội giao hàng chậm quá nhung vẫn cho sao',
#  'shop phục_vụ tận_tình mình rất hài_lòng',
#  'tôi về vất đi rồi chỉ đc quảng_cáo hay thôi đã thế lại còn đắt nữa chứ',
#  'hàng i_hình luôn đẹp cực_kì shop giao hàng nhanh nữa hihi áo đẹp quá e phải sửa lại fb nè áo đẹp quá shop',
#  'thanks shop',
#  'ko như mong_đợi',
#  'vải xấu k_thể mặc nổi mua lần cạch đéo có lần sau',
#  'thời_gian giao hàng nhanh',
#  'phản_hồi shop thì shop nói cũng có cho đổi đấy nhưng phải mất_phí vận_chuyển tự_nhiên phải mất thêm tiền',
#  'cảm_ơn shop nhiều nhiều',
#  'phần vai áo quá rộng ko đúng form áo nhưng sửa_tí là ok',
#  'cặp dáng xấu',
#  'hàng giống hình',
#  'nếu dùng ổn mk sẽ tiếp_tục ủng_hộ shop',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền rất đáng tiền',
#  'size kg nhưng mình kg mặc đã chật',
#  'rộng quá shop cho em đổi lại aiize s vs ạ',
#  'thất_vọng',
#  'làm_ăn k ra gì',
#  'm đặt cafe shop giao màu xanh',
#  'sản_phẩm như hình phục_vụ nhiệt_tình giao hàng đúng thời_gian',
#  'áo ko có giống hình',
#  'chất vải mát',
#  'cổ chật',
#  'săn deal dc k bao_bì đẹp ngòi_bút ổn nhưng mực nhanh bay màu thành từng mảng',
#  'như lần trước áo đẹp khỏi chê',
#  'khi dùng thơm và mềm môi',
#  'túi gì mà đẹp dữ_thần thiên_địa',
#  'thiếu cái lót giày',
#  'rẻ thế_này mà áo đc y_hình',
#  'áo đẹp lắm thích hơp vs các ban mặc sexy_tí vì phần nách hơi sâu vải dày mát',
#  'shop gửi nhầm size bé tí k mặc đc lấy bộ mà vừa bé tí',
#  'như quần_mặc thể_dục',
#  'chất_lượng sản_phẩm tuyệt_vời bảo_hành điện_tử nên được thêm năm bảo_hành',
#  'áo xinh vừa vặn luôn chất vải khó dão có_điều hơi nóng_xíu',
#  'khá thất_vọng về màu của sp',
#  'bỉm để lâu',
#  'mới bóc thì đẹp',
#  'rồi đem vứt',
#  'giao ko đúng mẫu đặt nghĩ sao đặt mẫu k giao mẫu k vui thật buôn_bán mà đẩy hàng tồn cho khách kiểu đó đổi trả rắc_rối nên đành chịu vì gần sinh r',
#  'các mác áo_đính trực_tiếp vào thân áo đều đã bị giựt ra',
#  'áo kiểu_dáng như hình_chất vải hơi xấu mua cũng đc',
#  'vừa mặc đc tiếng đã bị xù lông',
#  'áo đẹp giống hình',
#  'thời_gian giao hàng rất nhanh',
#  'lấy màu xanh_dương nhưng shop giao màu xanh rêu',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'chất_lượng sản_phẩm rất kém đóng_gói sản_phẩm rất kém',
#  'chất_lượng tốt giá rẻ',
#  'k gởi hàng',
#  'mua lần rồi mà lần nào hàng cũg rất đẹp',
#  'áo đẹp vừa tiền nhưng size m thì nhìn tương_đương với size s',
#  'gửi sai hàng size s thì lấy size l',
#  'tay_áo không dài như hình nhưng cũng khá xinh_chất_liệu vải mềm mịn',
#  'con mình rất thik',
#  'chất_lượng sản_phẩm rất kém',
#  'chất_lượng sản_phẩm cực_kì kém áo bé hơn nhiều so với mô_tả mặc vào vừa cộc vừa chật_sai hoàn_toàn dáng áo thời_gian chuẩn_bị hàng lâu hơn nhiều so với các shop khác làm_ăn gì như lừa_đảo nói_chung mất tiền ngu lần sau không bao_giờ quay lại',
#  'giày đi ok nhưng hơi bẩn',
#  'giá quá rẻ so với chất_lượng',
#  'chất luợng sp tốt',
#  'vải cầm nặng tay',
#  'vải dày fom y_hình',
#  'chất đẹp đáng tiền mỗi tội áo này chỉ hợp vs ng kg trên m thôi',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn noi chung là ok',
#  'mới dùng chưa rõ tác_dụng nhưng thấy cũng ổn',
#  'quần bị ngắn nếu người m',
#  'shop phục_vụ quá kém',
#  'mong shop chú_ý cách gói hàng hơn',
#  'chưa nào mua hàng và vừa rẻ vừa đẹp như_vậy',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn hàng dep yk_hình',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'chất vải mặc vào khá ngứa',
#  'áo bị vết bẩn giặt xong vẫn còn ko sạch vết',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'kiểu_dáng thì đc mà đi ko chắc chân',
#  'cảm_ơn shop nhé',
#  'đc cái shop gửi hàng nhanh nhiệt_tình nên vẫn cho shop sao',
#  'đường may quá xấu',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn chất_lượng sản_phẩm tuyệt_vời rất đáng tiền quần giống y_hình đẹp',
#  'rất ưng',
#  'quá rộng',
#  'rất thích',
#  'còn được tặng thêm đôi vớ sẽ ủng_hộ shop vào lần sau ạ',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'chất_lượng sản_phẩm tạm được túi mỏng đựng rác phải túi',
#  'sản_phẩm ko_đẹp như hình',
#  'phu c vu giao ha ng sa_n phâ m râ t ok',
#  'đã mua nhiều lần',
#  'tuyệt_vời các bạn hãy cứ yên_tâm mà mua nhé',
#  'chất_lượng oki giao hàng nhanh',
#  'giặt xong phơi khô có mùi hôi ko_thơm quần_áo',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn hơi to nhưng hàng oke',
#  'phom áo rộng',
#  'vải quá mòng',
#  'mua áo mà chất khác nhau',
#  'vận_chuyển quá kém',
#  'hàng đẹp lắm thanks_shop chỉ là đọc ko kỹ miếng dán dạng lưới mà thành miếng dán lưới nên hơi bùn vs lại shop giao_hơi lâu sẽ ủng_hộ',
#  'áo thì vải tạm chấp_nhận được tay hơi dài',
#  'mình đặt side m mà giao side l',
#  'chất vải xấu bai nhão giao hàng chậm',
#  'có tem kiểm_chống hàng giả',
#  'chất_lượng len tốt',
#  'thời_gian giao hàng tạm được',
#  'chất_lượng sản_phẩm rất kém rất rất kém_hình một đằng thực_tế một nẻo quần thì rộng to size_s mà như l_quần thì lưng ngắn quá mức cho_phép k tới mức vừa chứ đừng nói là lưng cao_form không ôm rộng rộng xấu kinh_khủng',
#  'bị bung chỉ nhiều',
#  'nói_chung là không thất_vọng đâu',
#  'a o be ko đu_ng mâ u_vơ i a_o ba me',
#  'chất_lượng sản_phẩm rất kém rất không đáng tiền áo form rộng quá tệ vô_cùng luôn',
#  'cổ và tay nhỏ hơn hình_mẫu',
#  'giao hàng lâu',
#  'hàng đẹp giá chuẩn nhưng chỗ gắn hoa vào hơi bị đùng chút',
#  'giày đc nhưng dù mang lớn hơn size lên vẫn chật',
#  'mình béo nên mặc váy hơi bị xòe nên xấu quá',
#  'chất da ok',
#  'không giống_hình lắm',
#  'mặc ko vừa to quá',
#  'shop giao thiếu quần_chất vải ổn so với giá tiền',
#  'thời_gian giao hàng rất nhanh chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'e đặt nhạt nhưng giao_đậm nhưng áo_xinh chất_lượng lắm ạ',
#  'đầm siêu_hở ngực',
#  'vải quá xấu_form và cắt không đẹp như hình mặc vào như cái ống tre',
#  'đóng_gói sản_phẩm chắc_chắn',
#  'bộ chấm bi_hồng k giống mẫu trên hình_bộ màu xanh thì giống',
#  'chất phù_hợp với giá tiền',
#  'áo hơi mỏng',
#  'nhưng phù_hợp giá tiền rồi',
#  'với giá này thì thắt_lưng tạm được',
#  'áo k đep_binh thưong',
#  'giá_cả chất luong',
#  'mặc rất thoải_mái',
#  'đàn rất đẹp ạ dù có lỗi nhỏ nhưng có_thể bỏ_qua',
#  'màu vàng xẫm không tươi_như trên hình mặc lên tối da',
#  'tôi rat hai long',
#  'hàng chuẩn',
#  'k giống ảnh',
#  'cảm_thấy rất ko hài_lòng vì mình đặt size xl mà tất_cả sản_phẩm nhận được đều size l',
#  'sản_phẩm ok',
#  'chất_lượng sản_phẩm k ưng',
#  'váy mỏng thôi',
#  'đặt cái trước xem vãi vũng ra làm_sao mà ai_ngờ đẹp quá',
#  'thời_gian giao hàng rất nhanh chất_lượng thì đôi giày hơi méo_xíu',
#  'nên mặc kèm váy_lót sẽ ổn hơn',
#  'chat luong tuyet voi thoi_gian giao hang nhanh',
#  'mà đế_giày của mình màu vàng mà',
#  'shop rất nhiệt_tình',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền shop phục_vụ rất tốt rất đáng tiền shop phục_vụ rất tốt đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền shop phục_vụ rất tốt',
#  'shop nên để size khi đặt lựa chứ hàng về sz nhỏ mặc chật_k thích lắm',
#  'bề ngang áo chật',
#  'chất vải đẹp nhưng from quá to',
#  'giày thì ok',
#  'thời_gian giao hàng rất nhanh',
#  'áo quá bé và ngắn so với hình_ảnh',
#  'mình rất ít khi đánh sao nhưng lầ này thật_sự quá thất_vọng',
#  'chữ e ở và chữ màu trắng trên áo bị mốc',
#  'nản',
#  'rep tn ngày',
#  'tuy thấy cỡ m cũng khá bự',
#  'phù_hợp giá tiền',
#  'những mặc vẫn ok',
#  'rất thất_vọng',
#  'manager quán mà_lại k hề biết về dkien sử_dụng e_voucher từ shopee',
#  'rất đáng tiền',
#  'hàng đẹp giao hàng nhanh',
#  'shop phục_vụ rất tốt thời_gian giao hàng rất nhanh rất đáng tiền',
#  'mất niềm tin',
#  'chất đẹp lắm thanks shop',
#  'quần với áo chất vải ok',
#  'chất_lượng sản_phẩm tạm được đóng_gói sản_phẩm tốt_bộ vải mềm_bộ vải cứng_đơ phù_hợp với giá tiền',
#  'giao hàng quá chậm',
#  'gói hàng rất kỹ lại còn được tặng quà nữa',
#  'nhìn hình_tưởng áo màu trắng_tinh nhưng lại là màu ngà mình ko thích',
#  'hàng may gia_công',
#  'tệ rất tệ',
#  'sản_phẩm mua chỉ có cái là đẹ',
#  'nên mua',
#  'mình cx ko bt là hàng cũ hay ms nữa',
#  'áo rách',
#  'áo mút mỏng mặc đẹp ngực nhỏ nên chọn size nhỏ hơn bình_thường bình_thường chọn',
#  'hihi',
#  'chất vải rất đẹp mình lấy size l_hơi rộng định_đổi nhưng chắc tự de ra tiệm sửa vậy',
#  'vải mềm ôm_dáng đẹp',
#  'đặt size_l nhưng lại giao size m bù lại sản_phẩm cũng rất ok giao hàng rất nhanh',
#  'váy hơi rộng',
#  'chất tóc đẹp',
#  'màu xanh o ngoai đậm hơn',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'dù_sao cũng rất ưng_ý',
#  'phục_vụ tốt',
#  'chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém đóng_gói sản_phẩm rất kém',
#  'túi zip bị hư nên k kéo bao lại đc',
#  'shop làm em tốn tìn mua áo mới rồi',
#  'đóg gói kg đạt giầy bj dơ_chùi kg ra',
#  'vừa in luôn vải đẹp mịn_màng yêu shop hiii',
#  'size m rong_lam',
#  'shop trả_lời chậm nhưng rất dễ_thương hàng đẹp',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'ao thi dược vay xấu quá',
#  'áo size m nhưng hơi dài',
#  'hàng cũng được',
#  'chua xem hàng cơ_mà giao hàng nhanh quá',
#  'áo bó phần dưới nên ko thích lắm',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền shop phục_vụ rất tốt_shop phục_vụ rất tốt thời_gian giao hàng rất nhanh',
#  'màu k giống_hình gì cả',
#  'áo dày dặn_chất đẹp lại rẻ',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'chất_lượng sản_phẩm ko giog',
#  'túi hầu_như k ngửi thấy mùi luôn ah',
#  'áo hơi rộng',
#  'đẹp nhưng hơi bị rộng tý',
#  'lừa_đảo',
#  'hàng được giao hàng nhanh_giá hợp_lí',
#  'chưa kết_luận về chất_lượng sản_phẩm được',
#  'mình đóng cho con chiếc con khó_chịu hay sao ấy cứ giằng_bỉm ra thôi',
#  'shop phục_vụ rất kém shop phục_vụ rất kém',
#  'áo hơi dài tí_thui mang kiểu form rộng cũng đẹp nè vải được hình_sao áo vậy',
#  'sản_phẩm rất đẹp nhé ai còn đắn_đo thì mua liền đi bao đẹp',
#  'cảm_ơn shop',
#  'kiểu_dáng đẹp',
#  'đương chỉ k chắc áo nhăn_nhúm rất không đáng tiền',
#  'sản_phẩm tốt giá rẻ',
#  'cứ tưởng áo vài thi ra là thun lạnh',
#  'chất_liệu bình_thường vì giá_thành cũng rẻ',
#  'giao hàng hơi lâu',
#  'vải váy tạm đc chất nylon nhiều phù_hợp giá tiền váy rộng so với bthg nên trừ_hao bớt',
#  'không phải hàng chính hãng dgw nhé nhưng đì cũng tạm được',
#  'chất áo đẹp nhưng vì mua onl nên khi nhận đc hàng m mặc thử lên thì thực_sự k đẹp hơi buồn',
#  'rách một đoạn bằng ngón tay phía sườn phải',
#  'hàng đẹp lắm ạ tuyệt_vời yêu shop',
#  'không đáng tin_cậy tư_vấn size nhưng đến khi giao đưa áo bé size quá to nhưng ko giải_quyết đổi hay j cho khách nhắn_tin ko trả_lời',
#  'áo giao cho mình bị vết bẩn gần tay_áo mình giặt không ra',
#  'ảnh thi đẹp ngoài thi xấu quá',
#  'sẽ ũng hộ shop nhiều hơn',
#  'bình_thường',
#  'đặt shop màu hồng mà shop ship cho màu vàng',
#  'mở mãi mới đc nên hơi bực',
#  'giày ngầu vl mua đi ae hihi',
#  'chất_lượng sản_phẩm tuyệt_vời nhưng chỉ mặc đk với những ng không có bụng mỡ khoảng thì nên mua còn hơn có bụng mỡ thì k nên vì sẽ chật_đẹp hơn mong_đợi',
#  'hơi rộng với mình',
#  'chuẩn_hình chất_lượng bán hàng rất có tâm',
#  'màu_sắc_đẹp chất vải nóng',
#  'thời_gian giao hàng nhanh đặt mùng mùng có hàng',
#  'mặc vào bao xinh',
#  'áo còn có khóa cài bằng nam_châm rất tiện_dụng cho người mặc',
#  'shop có_thể đổi áo cho mình ko',
#  'chất k đc đẹp',
#  'vừa nhận hàng xong và cảm_xúc là trời ạ',
#  'cái này thì vải thô lắm cân_nhắc mua cái khác thay_thế vì vải ko co_giãn và thô mấy váy khác của shọp thi ok',
#  'hàng này xài đã lắm mà phù_hợp túi_tiền nữa mn',
#  'vẫn ưng vì áo đẹp',
#  'vải đẹp',
#  'vải k được tốt',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền shop phục_vụ rất t áo mặc đẹp lắm ạ màu đen hay màu trắng cũng rất ưng ủng_hộ dài dài',
#  'khuyên anh_em chân_thành đừng bao jo mua hàng trên shoppe nữa',
#  'đóng_gói cẩn_thận',
#  'khuy không chắc_chắn chưa kịp cài đã rơi ra',
#  'sp ok',
#  'áo hơi mỏng nhưng mặc đẹp dây của áo hoàn_thiện ko đc tốt cho lắm mong_shop khắc_phục',
#  'chất_lượng sản_phẩm kém',
#  'chủ shop nhiệt_tình thích bảng mắt số lắm màu đẹp cực',
#  'hàng nhận được khác hình',
#  'shop tư_vấn tận_tình',
#  'áo không giống hình kh_xẻ vạt mà cổ lại cao',
#  'quần không giống hình_mẫu',
#  'hợp với giá',
#  'giao dài mà khác loại loại tạm đc loại quá tệ',
#  'mình lấy hai cái màu_da trắng đen mà shop chuyển hai cái màu đen luôn',
#  'chất len đẹp giao đúng giống hình',
#  'áo nhìn cũng được nhưng cái nơ ở cổ không đẹp cho lắm còn lại là đẹp',
#  'chất_lượng sản_phẩm ok',
#  'xấu thật',
#  'chất_lượng sản_phẩm tuyệt_vời vải đẹp lắm shop ơi',
#  'sản_phẩm đẹp như hình',
#  'hơi tiếc vì mua trước chương_trình giảm_giá',
#  'chất quần_mềm mặc khá thích lunnn lần sau sẽ ủng_hộ shop típ nà',
#  'đc tặng đoi_vớ nữa chứ hjhj chất_lượng sản_phẩm tuyệt_vời',
#  'mọi người nhớ mua nhiều ở shop hơn nhé',
#  'nó hơi rông hơn so voi sai',
#  'giày đẹp y_như hình giá rẻ giao hàng nhanh cám_ơn shop nhé',
#  'nhưng ksao nói_chung chất_lượng tốt',
#  'giao k đúng hàng',
#  'rất đáng tiền',
#  'nt thì kêu mặc rộng như mẫu mặc',
#  'hàng_không giống ảnh xấu',
#  'ko giong trong hình',
#  'áo ok có_điều tay_áo hơi nhỏ',
#  'chất_lượng sản_phẩm tạm được',
#  'đóng_gói sản_phẩm rất kém shop phục_vụ rất kém thời_gian giao hàng rất chậm',
#  'châ t đe p',
#  'áo giống hình',
#  'ai đánh_giá sao đều là người của shop à',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất nhiệt_tình',
#  'tạm chấp_nhận dc',
#  'không có gì để chê',
#  'vải quá đẹp',
#  'mong nhân_viên bên shop soạn hàng kĩ hơn',
#  'áo ko đúng hình',
#  'như màu cháo_lòng chứ ko phải trắng',
#  'tư_vấn nhiệt_tình',
#  'thời_gian giao hàng chậm chất_lượng sản_phẩm kém',
#  'yêu shop',
#  'các mẹ nên cân_nhắc trước khi mua hàng',
#  'so với giá k là đắt',
#  'mới nguyên mà hỏng luôn bên tai rồi',
#  'áo xô cứng xấu ko phải voan',
#  'vải bình_thường tiền nào vải ấy k sai',
#  'dan lam_ga gion ma luc nao cung giao ga dai',
#  'hàng vừa giá tiền',
#  'rộng và dày_dặn hết ý_e thấy ít ng đánh_giá nên cũng hơi lo kb áo nó có ổn_k mà hàng về nhìn là ưng ngay',
#  'áo mặc rất vừa người ko rộng cũng ko chặt',
#  'chất_lượng sản_phẩm tuyệt_vời giao hàng chậm rất đáng tiền',
#  'quần có hai caia bị lỗi còn lại ưng lắm',
#  'đúng hình vừa người ủng_hộ shop lần tới',
#  'phần nẹp váy may nhăn_nheo dúm_dó',
#  'dùng xong tóc khô nên cần dùng thêm dầu xả',
#  'mà cũng đẹp',
#  'chất_lượng sản_phẩm tuyệt_vời thời_gian giao hàng rất nhanh rất đáng tiền',
#  'shop phục_vụ tốt',
#  'chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém chất_lượng sản_phẩm rất kém rất không đáng tiền',
#  'chất_lượng sản_phẩm rất kém giao sai sản_phẩm shop phục_vụ rất kém',
#  'hang ko con qua giong nhu_da quay qua may',
#  'xong kêu mh tự đi sửa lun đồ bận chưa tới ngay đã tét tùm lum',
#  'cây còn bọc nilong sx cây ko bọc sx từ tháng',
#  'cạp chun vừa rộng vừa dão ko mặc đc cái nào hết',
#  'áo form ko đẹp nách áo bị hở khoản',
#  'áo giống hình nhưng size xl thực_sự quá nhỏ',
#  'định cho nhưng shop cứ hẹn lần hẹn_mòn nhưng vẫn ko thấy gửi bù cho m cái nắp',
#  'chất_lượng sản_phẩm tạm được',
#  'vải bình_thường hình in ko_sắc nét áo rộng so với size đưa ra',
#  'shop gửi thiếu hàng',
#  'chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời áo đẹp',
#  'troi oi sao hàng ko giống hình chất_liệu ko giống rộng to mà xấu quá troi nè_hình thì rõ đẹp',
#  'chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền rất đáng tiền thời_gian giao hàng rất nhanh',
#  'đồ xinh nhưng dịch_vụ chăm_sóc kha_ch hàng hơi kém',
#  'áo to_cực người mình hỏi tròn tý mua size m vẫn còn hơi rộng nhất là phần tay_áo',
#  'không hài_lòng về hàng',
#  'giao hàng nhanh gọn',
#  'hang ok',
#  'chất tạm đc mẫu_mã đc nhưng sp bị rách nhẹ lần sau shop nhớ kiểm_tra cẩn_thận nhé',
#  'áo vải quá xấu',
#  'mình chat với shop thì không thấy trả_lời',
#  'dùng để sào thì được chứ chiên rán ko đc vì nó hoàn_toàn không chống dính',
#  'form hơi rộng',
#  'thất_vọng ghê',
#  'ở trước ngực áo có mấy vệt trắng bẩn_cơ mà giặt sạch đi đc',
#  'chất đẹp',
#  'nhẹ ko rít mặt rất mỏng_thoáng nên làm kem lót trang_điểm ok ko bị dày_bịch như các kcn khác',
#  'va i đe p đươ ng may đe p_y hi_nh nhưng mi nh mă c hơi châ t',
#  'dày dặn form đẹp miệng túi hơi to nên cẩn_thận nếu k sẽ rơi_đồ từ túi',
#  'màu đẹp vải đẹp ngắn so với hình',
#  'e cảm_ơn',
#  'sản_phẩm không như mong_đợi',
#  'đặt sz nhưng trên áo là sz may ko quá chật',
#  'bên dài bên ngắn',
#  'nói thế cũng ngửi được',
#  'váy đẹp chất vải đũi mỏng đường may ẩu khg chắc_chắn',
#  'mình chọn xanh coban giao xanh da_trời nhưng không sao cũng được',
#  'shop check và giao hàng hơi lâu',
#  'cảm_ơn shop',
#  'chất_lượng sản_phẩm rất kém không giống hình',
#  'đắt',
#  'đẹp hết dức mong_đợ',
#  'ko trung_thực',
#  'hàng vải được nhưng vạt áo đương_may không đẹp tay_áo may_cng không đẹp',
#  'bọc sản_phẩm kín_đáo chặt_chẽ cẩn_thận nè chị chủ rep tin nhắn_siêu nhanh_siêu dễ_thương tư_vấn nhiệt_tình ạ',
#  'áo xinh vải đẹp',
#  'chất vải hơi bí_nóng',
#  'chất_lượng sản_phẩm tuyệt_vời áo đẹp',
#  'chất áo hơi mỏng',
#  'hợp với giá k',
#  'mình mặc vào nhìn như cái váy chống nắng_ý',
#  'mặc_dù đã ib và tha_thiết yêu_cầu shop che tên sản_phẩm giùm nhưg khi ghn là ng quen giao hàng tới hiện cái tên sp lù_lù ngượng chín cả mặt',
#  'đẹp',
#  'ảnh in đẹp',
#  'cổ hơi sâu',
#  'đang tính bỏ truyền_hình cap chỉ dùng cái này',
#  'chất vải đẹp',
#  'size hơi to',
#  'vải đẹp',
#  'áo mỏng vừa giá tiền',
#  'loại này ngoài chợ k cái',
#  'hàng kém chất_lượng ko dúng va_hình',
#  'shop bảo vải len nhưng nhận lại k phải',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn giao hàng siêu nhanh đặt thứ thứ đã nhận được hàng',
#  'rất đáng tiền',
#  'vải hơi cứng_ko biết giặt có mềm_ko nhưng nc là ok nên tăng size nhé mn ko sẽ bị kích_đũng đấy cao m thì mặc sẽ bị ngắn',
#  'mình giặt lần đầu bị phai màu đen',
#  'chất_lượng sản_phẩm tạm được',
#  'chất_lượng sản_phẩm tạm được',
#  'chất_lượng sản_phẩm rất kém không mặc nổi',
#  'đóng_gói hàng kém hộp bị méo',
#  'đen thôi đỏ quên đi nhưng ksao đã sửa và mặc vẫn ok',
#  'chất_lượng sản_phẩm tốt đóng_gói sản_phẩm chắc_chắn thời_gian giao hàng chậm shop phục_vụ khá tốt',
#  'nhìn áo_tưởng dày_dặn nhưng mua về thấy mỏng vải lại nóng',
#  'shop bán hàng quá dễ_thương mua hàng còn có quà tặng nữa sẽ ủng_hộ shop tiếp',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn hơi cộc so voi chiều cao của mh',
#  'sp nhận y_chang nội_dung quảng_cáo',
#  'không tốt lắm',
#  'đóng_gói và chất vải đều ok',
#  'chất_lượng sản_phẩm tuyệt_vời hang rat dep de thuong_lam rất đáng tiền shop phục_vụ rất tốt_tu van nhiet tinh_de thuong noi chung_la',
#  'mỏng tang',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói quá chán giao hàng hơi chậm',
#  'xau te',
#  'cô gái trong ảnh trắng_bóc nhìn còn đẹp',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn rất đáng tiền rất đáng tiền thời_gian giao hàng rất nhanh',
#  'tay_áo ko thêu',
#  'chất len rất xấu không như mong_đợi',
#  'có vết bẩn ở thân dày',
#  'màu ko giống như hình',
#  'mùi quá nồng mình nhận đc hàng mà phải vội_gói vào túi dán băng dính chặt mà mùi vẫn còn quanh_quẩn',
#  'huhu',
#  'shop phục_vụ rất kém cố_tình gửi sai hàng cho khách bán hàng ko_tâm_đức',
#  'gửi nhầm_mầu nhắn cho shop shop_k trả_lời',
#  'cũng tạm được',
#  'ko muốn quay lại',
#  'áo vải quá mỏng',
#  'giặt lần đầu chỉ ra màu xíu xiu rồi k ra màu nữa vào những lần giặt sau',
#  'áo không co_tu i ngay bu ng quâ n thi không tu i lưng quâ_n nên co_sơ i dây cô t đê co_gia n',
#  'ko tốt lắm',
#  'áo đẹp mát',
#  'đóng_gói sp rất tệ',
#  'mua size_l để mặc bầu mà váy hơi ôm có_vẻ ko bon_chen đc lâu',
#  'mình khá hài_lòng',
#  'rất hài_lòng',
#  'tuy_nhiên hàng bị lỗi phần mút lót phía trong bị lủng một lỗ bằng đầu ngón tay',
#  'nhưng đặt màu đen lại giao màu xanh',
#  'chất vải đẹp shop nhiệt_tình',
#  'không phải dáng ôm sát body size s vẫn khá rộng với mình dù mh cao m kg',
#  'hàng kém chất_lượng quá xấu',
#  'hàng đep',
#  'áo k ôm',
#  'ko đc đẹp lắm',
#  'tuyệt_vời',
#  'ship hàng đã cũ',
#  'chất_lượng sản_phẩm tạm ổn nhưng shop làm_ăn chán quá',
#  'hàng về rất nhanh và đẹp ạ_shop nói_chuyện rất dễ_thương và nhiệt_tình',
#  'sản_phẩm k giống_hình lắm mặc lần_dạn hết đường chỉ',
#  'giao sai màu',
#  'hàng ko giống hình',
#  'có quà nhỏ kẹo mút và giấy',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'tất_cả đều tuyệt_vời nhưng sản_phẩm may bị lỗi quá nhiều',
#  'chỉ là vì shop ở hà_nội nên giao hàng hơi lâu làm mình ở nhà_ngóng quá trời luôn',
#  'mát',
#  'vải ra màu',
#  'tạm chap nhận đc',
#  'quần đẹp nhưng_mà mới cầm tí tay đen_thui chắc là ra màu nhiều',
#  'bạn chủ shop rất nhiệt_tình và uy_tín',
#  'ra t co_giản nhung_hoi mỏng',
#  'ủng_hộ lâu_dài nói_chung hàng trên cả tuyệt_vời rất rất đep',
#  'tiền nào của nấy hic hic',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền lần đầu mình sẽ ủng_hộ shop tiếp ah',
#  'tuy_nhiên bạn nào tầm m thì sẽ ok hơn mình m mặc hơi cộc size xl',
#  'nhưng quạt_hơi bám bụi và dơ_nha',
#  'đóng_gói sản_phẩm chắc_chắn',
#  'nhưng với giá chỉ k như_vậy thì là khá ok ạ mình áp thêm code giảm_giá',
#  'màu hồng nhìn_tố xấu i quá ko sáng hồng như hình',
#  'áo đẹp nhưng màu đỏ_đô thì không chuẩn',
#  'chất vải tốt tuy_nhiên màu logo vàng sáng hơn so với hình',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền thời_gian giao hàng rất nhanh cảm_ơn shop nhiều shop làm_ăn rất tốt cảm_ơn shop',
#  'nếu chỉ màu trắng hoặc đen hoặc nâu thì tốt',
#  'không quá xuất_sắc nhưng hok quá xấu',
#  'quần đen_hơi rộng còn cái màu trắng may_túi màu cam nên mang vào hơi_kì nhưng nói_chung là cũng tạm được',
#  'mình đã nhận đươ c hàng và khá là ưng_ý',
#  'được',
#  'shop ơi',
#  'sai màu nhưng vải ok',
#  'giao nhầm size nữa chứ',
#  'thời_gian cb hàng và giao chậm',
#  'form body vải mịn đẹp giá hạt dẻ',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn áo đẹp thời_gian giao hàng rất nhanh',
#  'shop phục_vụ rất kém',
#  'size hơi nhỏ hơn bt nên mua s l vẫn bị chật',
#  'vải được nhưng thất_vọng khi đặt hai xái trắng kem lại giao một trắng kem và một cái trắng đục',
#  'siêu ngắn',
#  'm đã quá chán_đổi trả',
#  'shop nói tặng miếng mà ko thấy',
#  'mình kg mà mặc quần này bị trật luôn r',
#  'chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn shop phục_vụ rất tốt rất đáng tiền thời_gian giao hàng rất nhanh_be nha_minh rat thich',
#  'vải đẹp dày dặn chữ thêu cẩn_thận rõ nét form áo rộng',
#  'nhìn ngoài thì k vấn_đề gì nhưng sử_dụng thì',
#  'nt shop_k trả_lời',
#  'ao thi xau tien nao cua do',
#  'lỗi may nhìu chỉ thừa_nhăn nhíu lại',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'thank shop',
#  'dày dặn nhưng giặt bị phai nha',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'len hơi dão',
#  'thank shop nhé',
#  'chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'chọn màu trắng thì gửi màu cam',
#  'time giao hàng nhanh',
#  'đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'mình m bụng hơi rộng nhưng dài quần_ok d',
#  'dù mình chỉ có m',
#  'mặn mặn cay cay',
#  'ram lùn chạy tốt',
#  'vải hơi cứng',
#  'chất_lượng sản_phẩm tuyệt_vời',
#  'vẫn ủng_hộ shop nhưng hi_vọng nghe và sửa theo góp_ý của ng tiêu_dùng',
#  'vải hơi mỏng',
#  'chất_lượng tuyệt_vời thời_gian giao hàng tốt',
#  'nhưng mất cái bị lỗi',
#  'chất_lượng sản_phẩm rất kém shop làm_ăn ko uy_tín gửi hàng ko đúng hình',
#  'shop vui_vẻ nhiệt_tình và rất dễ_thương',
#  ...]

# %%
file_path = 'baomoi.model.bin'

try:
    model_embedding = KeyedVectors.load_word2vec_format(file_path, binary=True)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Model loaded successfully!

# %%
word_labels = list(model_embedding.key_to_index.keys())
max_seq = 100 
embedding_size = 400

def comment_embedding(comment):
    matrix = np.zeros((max_seq, embedding_size))
    words = comment.split()
    for i in range(min(len(words), max_seq)):
        word = words[i]
        if word in word_labels:
            matrix[i] = model_embedding[word]
    return matrix

# %%
train_data = [comment_embedding(review) for review in tqdm(reviews)]
train_data = np.array(train_data, dtype=np.float32)

label_data = []
for label in tqdm(labels):
    label_vec = np.zeros(3)
    try:
        label_vec[int(label)] = 1
    except:
        label_vec[0] = 1
    label_data.append(label_vec)
label_data = np.array(label_data)

x_train, x_test, y_train, y_test = train_test_split(train_data, label_data, test_size=0.2, random_state=42)
# Out:
# 100%|██████████| 18351/18351 [00:56<00:00, 325.17it/s]
# 100%|██████████| 18351/18351 [00:00<00:00, 646076.46it/s]

# %%
# 6. Chuẩn bị dữ liệu cho CNN
x_train = x_train.reshape(x_train.shape[0], max_seq, embedding_size, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], max_seq, embedding_size, 1).astype('float32')

# %%
# 7. Xây dựng mô hình CNN
num_classes = 3
filter_sizes = 3
num_filters = 150
dropout_rate = 0.5

model = keras.Sequential([
    layers.Conv2D(num_filters, (filter_sizes, embedding_size), activation='relu', input_shape=(max_seq, embedding_size, 1)),
    layers.MaxPooling2D(pool_size=(max_seq - filter_sizes + 1, 1)),
    layers.Dropout(dropout_rate),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 8. Huấn luyện mô hình
adam = tf.optimizers.Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

print(model.summary())
model.fit(x=x_train, y=y_train, batch_size=30, epochs=50, validation_data=(x_train, y_train))
model.save('models.h5')
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 1, 150)     │       180,150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 1, 1, 150)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 1, 150)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        19,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,865 (780.72 KB)
#  Trainable params: 199,865 (780.72 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.5184 - loss: 1.5146 - val_accuracy: 0.6282 - val_loss: 0.7636
# Epoch 2/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 38s 78ms/step - accuracy: 0.6154 - loss: 0.8460 - val_accuracy: 0.6407 - val_loss: 0.7994
# Epoch 3/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 72ms/step - accuracy: 0.6152 - loss: 0.8444 - val_accuracy: 0.6163 - val_loss: 0.8728
# Epoch 4/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.5862 - loss: 0.9576 - val_accuracy: 0.6686 - val_loss: 0.7783
# Epoch 5/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6212 - loss: 0.8846 - val_accuracy: 0.6611 - val_loss: 0.7841
# Epoch 6/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6110 - loss: 0.9013 - val_accuracy: 0.5677 - val_loss: 0.8908
# Epoch 7/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6343 - loss: 0.8496 - val_accuracy: 0.6715 - val_loss: 0.7528
# Epoch 8/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6467 - loss: 0.8345 - val_accuracy: 0.6909 - val_loss: 0.7178
# Epoch 9/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6467 - loss: 0.8157 - val_accuracy: 0.6965 - val_loss: 0.7078
# Epoch 10/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6380 - loss: 0.8694 - val_accuracy: 0.6899 - val_loss: 0.7762
# Epoch 11/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.6517 - loss: 0.8301 - val_accuracy: 0.6864 - val_loss: 0.7463
# Epoch 12/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 38s 77ms/step - accuracy: 0.6524 - loss: 0.8320 - val_accuracy: 0.6467 - val_loss: 0.7913
# Epoch 13/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 37s 76ms/step - accuracy: 0.6456 - loss: 0.8231 - val_accuracy: 0.7095 - val_loss: 0.7114
# Epoch 14/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6400 - loss: 0.8310 - val_accuracy: 0.6230 - val_loss: 0.8331
# Epoch 15/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 69ms/step - accuracy: 0.6591 - loss: 0.8045 - val_accuracy: 0.4780 - val_loss: 0.9040
# Epoch 16/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6464 - loss: 0.8116 - val_accuracy: 0.6990 - val_loss: 0.7063
# Epoch 17/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6377 - loss: 0.8458 - val_accuracy: 0.6914 - val_loss: 0.7323
# Epoch 18/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6636 - loss: 0.8008 - val_accuracy: 0.6796 - val_loss: 0.7437
# Epoch 19/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 74ms/step - accuracy: 0.6520 - loss: 0.8101 - val_accuracy: 0.6978 - val_loss: 0.6944
# Epoch 20/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 69ms/step - accuracy: 0.6723 - loss: 0.7771 - val_accuracy: 0.7181 - val_loss: 0.6575
# Epoch 21/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 72ms/step - accuracy: 0.6606 - loss: 0.7927 - val_accuracy: 0.6953 - val_loss: 0.7773
# Epoch 22/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 69ms/step - accuracy: 0.6666 - loss: 0.8379 - val_accuracy: 0.4873 - val_loss: 0.9124
# Epoch 23/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 37s 75ms/step - accuracy: 0.6615 - loss: 0.7961 - val_accuracy: 0.6612 - val_loss: 0.7634
# Epoch 24/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 33s 68ms/step - accuracy: 0.6601 - loss: 0.8156 - val_accuracy: 0.7198 - val_loss: 0.6595
# Epoch 25/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 33s 67ms/step - accuracy: 0.6621 - loss: 0.8387 - val_accuracy: 0.7191 - val_loss: 0.6786
# Epoch 26/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 38s 77ms/step - accuracy: 0.6679 - loss: 0.7960 - val_accuracy: 0.7012 - val_loss: 0.7539
# Epoch 27/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6735 - loss: 0.7713 - val_accuracy: 0.7258 - val_loss: 0.6808
# Epoch 28/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6721 - loss: 0.7720 - val_accuracy: 0.6177 - val_loss: 0.7645
# Epoch 29/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6729 - loss: 0.7752 - val_accuracy: 0.7270 - val_loss: 0.6333
# Epoch 30/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6807 - loss: 0.7552 - val_accuracy: 0.7050 - val_loss: 0.6893
# Epoch 31/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 74ms/step - accuracy: 0.6699 - loss: 0.7817 - val_accuracy: 0.7262 - val_loss: 0.6345
# Epoch 32/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6745 - loss: 0.7667 - val_accuracy: 0.7060 - val_loss: 0.6987
# Epoch 33/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 74ms/step - accuracy: 0.6645 - loss: 0.7938 - val_accuracy: 0.7198 - val_loss: 0.6695
# Epoch 34/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6806 - loss: 0.7628 - val_accuracy: 0.7244 - val_loss: 0.6605
# Epoch 35/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6847 - loss: 0.7399 - val_accuracy: 0.6873 - val_loss: 0.7167
# Epoch 36/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6778 - loss: 0.7662 - val_accuracy: 0.7415 - val_loss: 0.6206
# Epoch 37/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6946 - loss: 0.7407 - val_accuracy: 0.7392 - val_loss: 0.6170
# Epoch 38/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6869 - loss: 0.7619 - val_accuracy: 0.7057 - val_loss: 0.6651
# Epoch 39/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.6717 - loss: 0.7738 - val_accuracy: 0.7269 - val_loss: 0.6472
# Epoch 40/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 72ms/step - accuracy: 0.6871 - loss: 0.7350 - val_accuracy: 0.6763 - val_loss: 0.7074
# Epoch 41/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.7002 - loss: 0.7184 - val_accuracy: 0.7415 - val_loss: 0.6347
# Epoch 42/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6871 - loss: 0.7405 - val_accuracy: 0.7476 - val_loss: 0.6092
# Epoch 43/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6862 - loss: 0.7522 - val_accuracy: 0.7355 - val_loss: 0.6483
# Epoch 44/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 74ms/step - accuracy: 0.6828 - loss: 0.7575 - val_accuracy: 0.7257 - val_loss: 0.6509
# Epoch 45/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 73ms/step - accuracy: 0.6820 - loss: 0.7733 - val_accuracy: 0.7420 - val_loss: 0.6285
# Epoch 46/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 74ms/step - accuracy: 0.6938 - loss: 0.7333 - val_accuracy: 0.5996 - val_loss: 0.8151
# Epoch 47/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 69ms/step - accuracy: 0.6897 - loss: 0.7303 - val_accuracy: 0.7478 - val_loss: 0.6092
# Epoch 48/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 35s 71ms/step - accuracy: 0.7008 - loss: 0.7131 - val_accuracy: 0.7360 - val_loss: 0.6276
# Epoch 49/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 36s 72ms/step - accuracy: 0.7012 - loss: 0.7119 - val_accuracy: 0.7088 - val_loss: 0.6697
# Epoch 50/50
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.6932 - loss: 0.7516 - val_accuracy: 0.7379 - val_loss: 0.6166
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import classification_report, accuracy_score

# Dự đoán trên tập kiểm tra
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

accuracy = accuracy_score(y_true_classes, y_pred_classes)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#          NEG       0.69      0.80      0.74      1318
#          NEU       0.40      0.12      0.19       937
#          POS       0.68      0.89      0.77      1416
#
#     accuracy                           0.66      3671
#    macro avg       0.59      0.60      0.57      3671
# weighted avg       0.61      0.66      0.61      3671
#
# Accuracy: 66.11%

# %%
# 9. Lưu mô hình
model.save('models.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
